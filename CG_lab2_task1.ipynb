# %%
from skimage.io import imshow, imsave, imread
from skimage import img_as_float
from skimage.color import rgb2gray, rgb2hsv, hsv2rgb
from numpy import dstack
import numpy as np
from matplotlib import pyplot as plt

# %%
def rgb_to_gray_1(path):
    img = imread(path)
    r = img[:,:,0]
    g = img[:,:,1]
    b = img[:,:,2]
    return (r*0.2126+g*0.7152+b*0.0722)
    
def rgb_to_gray_2(path):
    img = imread(path)
    r = img[:,:,0]
    g = img[:,:,1]
    b = img[:,:,2]
    return (r*0.299+g*0.587+b*0.114)

# %% [markdown]
# # ЗАДАНИЕ 1. Преобразовать изображение из RGB в оттенки серого. Реализовать два варианта формулы с учетом разных вкладов R, G и B в интенсивность (см презентацию). Затем найти разность полученных полутоновых изображений. Построить гистограммы интенсивности после одного и второго преобразования.

# %% [markdown]
# ### Gray 1

# %%
path = "marvel.jpg"

# %%
gray1 = rgb_to_gray_1(path) 
imshow(gray1, cmap='gray');
# Out:
# D:\Programs\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:80: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   warn("Float image out of standard range; displaying "

# %% [markdown]
# ### Gray 2

# %%
gray2 = rgb_to_gray_2(path)
imshow(gray2, cmap='gray');

# %% [markdown]
# ### Difference between Gray 1 and Gray 2

# %%
imshow(abs(gray1-gray2), cmap='gray')

# %% [markdown]
# ## Hist of Gray 1

# %%
a = imread(path)
plt.hist(rgb_to_gray_1(path), facecolor = "gray");
plt.xlabel("Intensity");
plt.ylabel("Count of pixels");

# %% [markdown]
# ## Hist of Gray 2

# %%
a = imread(path)
plt.hist(rgb_to_gray_2(path), facecolor = "gray");
plt.xlabel("Intensity");
plt.ylabel("Count of pixels");
